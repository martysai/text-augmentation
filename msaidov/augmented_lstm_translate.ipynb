# %% [markdown]
# # Augmentation API usage

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install --upgrade torch
# !pip install --upgrade wandb
# !pip install --upgrade catalyst
# !pip install --upgrade torchtext
# !wandb login c54b2fcb6b8ca2808f5be303a8a3b6e464f52cca
# Out:
# Requirement already up-to-date: torch in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already up-to-date: wandb in /usr/local/lib/python3.6/dist-packages (0.8.32)
# Requirement already satisfied, skipping upgrade: watchdog>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.10.2)
# Requirement already satisfied, skipping upgrade: sentry-sdk>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.14.3)
# Requirement already satisfied, skipping upgrade: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied, skipping upgrade: subprocess32>=3.5.3 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied, skipping upgrade: configparser>=3.8.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.0.0)
# Requirement already satisfied, skipping upgrade: docker-pycreds>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied, skipping upgrade: gql==0.2.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.2.0)
# Requirement already satisfied, skipping upgrade: GitPython>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.1.1)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.21.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.12.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied, skipping upgrade: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.1.1)
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.352.0)
# Requirement already satisfied, skipping upgrade: shortuuid>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.0.1)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.13)
# Requirement already satisfied, skipping upgrade: pathtools>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from watchdog>=0.8.3->wandb) (0.1.2)
# Requirement already satisfied, skipping upgrade: certifi in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: urllib3>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (1.24.3)
# Requirement already satisfied, skipping upgrade: graphql-core<2,>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb) (1.1)
# Requirement already satisfied, skipping upgrade: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb) (2.3)
# Requirement already satisfied, skipping upgrade: gitdb<5,>=4.0.1 in /usr/local/lib/python3.6/dist-packages (from GitPython>=1.0.0->wandb) (4.0.4)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (2.8)
# Requirement already satisfied, skipping upgrade: smmap<4,>=3.0.1 in /usr/local/lib/python3.6/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (3.0.2)
# Requirement already up-to-date: catalyst in /usr/local/lib/python3.6/dist-packages (20.4.1)
# Requirement already satisfied, skipping upgrade: Pillow<7 in /usr/local/lib/python3.6/dist-packages (from catalyst) (6.2.2)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.6/dist-packages (from catalyst) (20.3)
# Requirement already satisfied, skipping upgrade: plotly>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from catalyst) (4.4.1)
# Requirement already satisfied, skipping upgrade: crc32c>=1.7 in /usr/local/lib/python3.6/dist-packages (from catalyst) (2.0)
# Requirement already satisfied, skipping upgrade: tensorboardX in /usr/local/lib/python3.6/dist-packages (from catalyst) (2.0)
# Requirement already satisfied, skipping upgrade: tqdm>=4.33.0 in /usr/local/lib/python3.6/dist-packages (from catalyst) (4.38.0)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20 in /usr/local/lib/python3.6/dist-packages (from catalyst) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: imageio in /usr/local/lib/python3.6/dist-packages (from catalyst) (2.4.1)
# Requirement already satisfied, skipping upgrade: deprecation in /usr/local/lib/python3.6/dist-packages (from catalyst) (2.0.7)
# Requirement already satisfied, skipping upgrade: tensorboard>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from catalyst) (2.2.0)
# Requirement already satisfied, skipping upgrade: torchvision>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from catalyst) (0.5.0)
# Requirement already satisfied, skipping upgrade: opencv-python in /usr/local/lib/python3.6/dist-packages (from catalyst) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.14.2 in /usr/local/lib/python3.6/dist-packages (from catalyst) (0.16.2)
# Requirement already satisfied, skipping upgrade: matplotlib in /usr/local/lib/python3.6/dist-packages (from catalyst) (3.2.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.22 in /usr/local/lib/python3.6/dist-packages (from catalyst) (1.0.3)
# Requirement already satisfied, skipping upgrade: GitPython>=2.1.11 in /usr/local/lib/python3.6/dist-packages (from catalyst) (3.1.1)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from catalyst) (3.13)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.4 in /usr/local/lib/python3.6/dist-packages (from catalyst) (1.18.2)
# Requirement already satisfied, skipping upgrade: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from catalyst) (1.4.0)
# Requirement already satisfied, skipping upgrade: seaborn in /usr/local/lib/python3.6/dist-packages (from catalyst) (0.10.0)
# Requirement already satisfied, skipping upgrade: ipython in /usr/local/lib/python3.6/dist-packages (from catalyst) (5.5.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->catalyst) (2.4.7)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from packaging->catalyst) (1.12.0)
# Requirement already satisfied, skipping upgrade: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly>=4.1.0->catalyst) (1.3.3)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX->catalyst) (3.10.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20->catalyst) (0.14.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20->catalyst) (1.4.1)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (2.21.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (46.1.3)
# Requirement already satisfied, skipping upgrade: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (1.28.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (1.7.2)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (1.6.0.post3)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (1.0.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (3.2.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (0.34.2)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (0.4.1)
# Requirement already satisfied, skipping upgrade: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14.0->catalyst) (0.9.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.14.2->catalyst) (2.4)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.14.2->catalyst) (1.1.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->catalyst) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->catalyst) (1.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->catalyst) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.22->catalyst) (2018.9)
# Requirement already satisfied, skipping upgrade: gitdb<5,>=4.0.1 in /usr/local/lib/python3.6/dist-packages (from GitPython>=2.1.11->catalyst) (4.0.4)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->catalyst) (4.3.3)
# Requirement already satisfied, skipping upgrade: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->catalyst) (2.1.3)
# Requirement already satisfied, skipping upgrade: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->catalyst) (4.4.2)
# Requirement already satisfied, skipping upgrade: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->catalyst) (0.8.1)
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->catalyst) (0.7.5)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->catalyst) (4.8.0)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->catalyst) (1.0.18)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (4.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14.0->catalyst) (1.3.0)
# Requirement already satisfied, skipping upgrade: smmap<4,>=3.0.1 in /usr/local/lib/python3.6/dist-packages (from gitdb<5,>=4.0.1->GitPython>=2.1.11->catalyst) (3.0.2)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->catalyst) (0.2.0)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->catalyst) (0.6.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->catalyst) (0.1.9)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14.0->catalyst) (3.1.0)
# Requirement already up-to-date: torchtext in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied, skipping upgrade: sentencepiece in /usr/local/lib/python3.6/dist-packages (from torchtext) (0.1.85)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext) (4.38.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.12.0)
# Requirement already satisfied, skipping upgrade: torch in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.4.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.18.2)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from torchtext) (2.21.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (3.0.4)
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Successfully logged in to Weights & Biases!

# %%
import pandas as pd
import numpy as np
import os
from google.cloud import translate_v2 as translate
import six
import torch
from catalyst import dl
import torch.nn as nn
import pdb
from torch import cuda
import torch.nn.functional as F
from sklearn.metrics import accuracy_score
import sys
import torchtext
from torchtext import data
from torchtext.data import BPTTIterator, BucketIterator, Iterator
from torchtext import datasets
import torch.optim as O
from tqdm import tqdm
import datetime
import time
import catalyst
import wandb
from torch.utils.data import Dataset, DataLoader, TensorDataset

DEVICE = 'cuda'
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# alchemy not available, to install alchemy, run `pip install alchemy-catalyst`.

# %%
print("PyTorch Version:", torch.__version__)
print("Catalyst Version:", catalyst.__version__)
print("Wandb Version:", wandb.__version__)
# Out:
# PyTorch Version: 1.4.0
# Catalyst Version: 20.04.1
# Wandb Version: 0.8.32

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "drive/My Drive/text-augmentation/text-augmentation.json"

# %%
def make_translation(text, target='ru'):
    translate_client = translate.Client()

    if isinstance(text, six.binary_type):
        text = text.decode('utf-8')

    result = translate_client.translate(
        text, target_language=target)

    return result['translatedText'], result['detectedSourceLanguage']

# %%
print(make_translation("yes, this example works fine"))

# %%
translate_client = translate.Client()
source_language = 'en'
target_language = 'ru'
def back_translation(text):
    global translate_client, target_language, source_lanaguage

    if isinstance(text, six.binary_type):
        text = text.decode('utf-8')

    forward = translate_client.translate(text, target_language=target_language)
    res = translate_client.translate(forward['translatedText'], target_language=source_language)
    return res['translatedText']

# %%
print(back_translation("Complicated sentence in order to transform its representation but not meaning"))

# %% [markdown]
# # Model description

# %%
class BiLstm(nn.Module):
    def __init__(self, vocab_size, h_size, n_layers, dropout, padding_idx):
        super(BiLstm, self).__init__()
        self.embedding = nn.Embedding(vocab_size, h_size, padding_idx=padding_idx, scale_grad_by_freq=True)
        self.lstm = nn.LSTM(h_size, h_size, n_layers, bidirectional=True, dropout=dropout)
        self.out = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(2 * 4 * n_layers * h_size, h_size * 3),
            nn.BatchNorm1d(h_size * 3),
            nn.PReLU(),
            nn.Dropout(dropout),
            nn.Linear(h_size * 3, h_size * 3),
            nn.BatchNorm1d(h_size * 3),
            nn.PReLU(),
            nn.Dropout(dropout),
            nn.Linear(h_size * 3, 3)
        )

        self.init_weights()

    def forward(self, batch):
        prem, hyp = batch
        prem, prem_len = prem
        hyp, hyp_len = hyp

        prem, hyp = self.embedding(prem), self.embedding(hyp)

        # optimize perfomance of RNN by omitting padding token
        prem = nn.utils.rnn.pack_padded_sequence(input=prem, lengths=prem_len, enforce_sorted=False)
        hyp = nn.utils.rnn.pack_padded_sequence(input=hyp, lengths=hyp_len, enforce_sorted=False)
        _, h_prem = self.lstm(prem)
        _, h_hyp = self.lstm(hyp)

        h_prem = torch.cat(h_prem, dim=-1)
        h_prem = h_prem.permute(1,0,2)
        h_prem = h_prem.contiguous().view(h_prem.size(0),-1)

        h_hyp = torch.cat(h_hyp, dim=-1)
        h_hyp = h_hyp.permute(1,0,2)
        h_hyp = h_hyp.contiguous().view(h_hyp.size(0),-1)

        h = torch.cat([h_prem, h_hyp],dim=-1)
        h = h.contiguous().view(h.size(0), -1)
        
        return self.out(h)
 
    def init_weights(self):
        d = self.embedding.weight.size(1)
        nn.init.uniform_(self.embedding.weight, -1.0 / np.sqrt(d), 1.0 / np.sqrt(d))

# %% [markdown]
# # Training with augmentation

# %%
TEXT = torchtext.data.Field(lower=True, tokenize='spacy', include_lengths=True)
LABEL = torchtext.data.LabelField(sequential=False, is_target=True)

train, valid, test = datasets.SNLI.splits(TEXT, LABEL)

# %%
print("Example properties:", dir(train.examples[0]))
# Out:
# Example properties: ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'fromCSV', 'fromJSON', 'fromdict', 'fromlist', 'fromtree', 'hypothesis', 'label', 'premise']

# %%
used_indices = set()

# %%
import numpy as np
import pandas as pd

data = np.full((0, 3), "")

sent1 = "some sent 1"
sent2 = "some sent 2"
appendix = np.array([sent1, sent2, "neutral"])
data = np.vstack((data, appendix.reshape((1, -1))))
print(data)

data = np.full((0, 3), "")
# Out:
# [['some sent 1' 'some sent 2' 'neutral']]

# %% [markdown]
# # Augmentation implementation (don't run if you have csv)

# %%
def save_in_csv(data):
    save_augmented_objects = pd.DataFrame(data=data, columns=['premise', 'hypothesis', 'label'])
    save_augmented_objects.to_csv("drive/My Drive/text-augmentation/augmented.csv", index=False)
    return

# %%
# Unite two datasets: source and augmented
ALREADY_SAVED = 15205
AUGMENTED_RATIO = 0.1
count_augmented_objects = 0
bad_examples = 0
print("Remained to load:", AUGMENTED_RATIO * len(train.examples) - ALREADY_SAVED)
start = time.time()
while count_augmented_objects < AUGMENTED_RATIO * len(train.examples) - ALREADY_SAVED:
    if count_augmented_objects % 10 == 5:
        print(data.shape[0])
    if count_augmented_objects % 100 == 5:
        print("Successful augmented objects, bad examples:", count_augmented_objects, bad_examples)
        print("Done in %.2f" % (time.time() - start))
        start = time.time()
        print("5 random saved objects:")
        indices = np.random.choice(np.arange(data.shape[0]), size=5)
        print(data[indices, :])
        print("size of set:", len(used_indices))
        save_in_csv(data)

    rand_ind = int(np.random.random() * len(train.examples))
    while rand_ind in used_indices:
        rand_ind = int(np.random.random() * len(train.examples))
    used_indices.add(rand_ind)
    premise, hypothesis, label = train.examples[rand_ind].hypothesis, train.examples[rand_ind].premise, \
                                 train.examples[rand_ind].label
    joined_premise, joined_hypothesis = ' '.join(premise), ' '.join(hypothesis)
    back_premise, back_hypothesis = back_translation(joined_premise), back_translation(joined_hypothesis)
    if joined_premise != back_premise and joined_hypothesis != back_hypothesis:
        count_augmented_objects += 1
        new_example = torchtext.data.example.Example()
        new_example.premise = back_premise.split()
        new_example.hypothesis = back_hypothesis.split()
        new_example.label = label
        train.examples.append(new_example)
        appendix = np.array([back_premise, back_hypothesis, label]).reshape((1, -1))
        data = np.vstack((data, appendix))
    else:
        bad_examples += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# 25305
# Successful augmented objects, bad examples: 25305 1694
# Done in 46.43
# 5 random saved objects:
# [['The boy first tries mountain biking.'
#   'A young Caucasian man in shorts, a T-shirt, helmet and sunglasses rides a mountain bike down a heavily wooded hill.'
#   'neutral']
#  ['girl drinks her soda in the aquarium.'
#   'girl drinks from straw, sitting near a glass of dolphinarium.'
#   'neutral']
#  ['baby sleeps on the street.'
#   'a small child in a stocking and a bright jacket runs away from the bench.'
#   'contradiction']
#  ['children read calmly inside the building.'
#   'Children play ball on the street in front of the building.'
#   'contradiction']
#  ['the ball is light.' 'young boys play ball on the beach.' 'neutral']]
# size of set: 43257
# 25315
# 25325
# 25335
# 25345
# 25355
# 25355
# 25365
# 25375
# 25385
# 25395
# 25405
# Successful augmented objects, bad examples: 25405 1705
# Done in 46.26
# 5 random saved objects:
# [['old people holding hands at the grand opening'
#   'three old men lay their hands on each other at the grand opening.'
#   'entailment']
#  ['man caresses his guitar.'
#   'An elderly African American man playing an electric guitar on a public street.'
#   'neutral']
#  ['woman crosses the road.'
#   'A woman walks along the road, using an umbrella to protect her from the sun.'
#   'entailment']
#  ['a man wears a helmet and sunglasses, but he is not happy.'
#   'a man in a helmet and sunglasses smiles.' 'neutral']
#  ['team and woman in black dress at the party dance.'
#   'a crew with cameras and a woman in a black dress surround a gray van.'
#   'contradiction']]
# size of set: 43368
# 25415
# 25415
# 25425
# 25435
# 25445
# 25455
# 25465
# 25475
# 25485
# 25495
# 25505
# Successful augmented objects, bad examples: 25505 1717
# Done in 45.22
# 5 random saved objects:
# [['two men understand each other'
#   'left man plays the violin; on the right, a man plays the harp.'
#   'contradiction']
#  ['man is looking at the newspaper.'
#   'woman reading a newspaper in the subway.' 'entailment']
#  ['two cats are sleeping.'
#   'two dogs are fighting in bed, with a French door and a Persian carpet in the background.'
#   'contradiction']
#  ['baseball player on the mound.'
#   'baseball player takes the mound in an open stadium.' 'entailment']
#  ['Ratatouille actually makes soup'
#   'Three men are cooking in a large kitchen.' 'contradiction']]
# size of set: 43480
# 25515
# 25525
# 25535
# 25545
# 25555
# 25565
# 25575
# 25585
# 25585
# 25595
# 25605
# Successful augmented objects, bad examples: 25605 1726
# Done in 42.80
# 5 random saved objects:
# [['people look happy.'
#   'people look at the construction on a city street.' 'neutral']
#  ['a little girl runs away from someone during the game.'
#   'a little girl runs along a brightly lit corridor.' 'neutral']
#  ['man on the street'
#   'A man wrapped in a flag is walking along the street.' 'entailment']
#  ['A man steals a statue.'
#   'A man on a mechanical elevator in a helmet assembles a statue.'
#   'contradiction']
#  ['several workers at work.'
#   'two builders are working on infrastructure, and one worker is resting.'
#   'entailment']]
# size of set: 43589
# 25615
# 25625
# 25635
# 25645
# 25655
# 25665
# 25675
# 25675
# 25685
# 25695
# 25705
# Successful augmented objects, bad examples: 25705 1734
# Done in 44.40
# 5 random saved objects:
# [['four men are inside the warehouse and look through the boxes.'
#   'four males with a camera and backpacks inside a warehouse with puddles on the water on the floor and graffiti on the walls.'
#   'contradiction']
#  ['A man listens to headphones to increase their volume.'
#   'a man in a diamond sweater and jeans stands in the middle of the sidewalk, listening to headphones.'
#   'neutral']
#  ['little boy swims in the lava.'
#   'A little boy in red shorts with blue flowers sits on a shovel in the grass near the solarium.'
#   'contradiction']
#  ['Stan kicked the ball to his son while playing kickball.'
#   'Asian man is kicking something to someone.' 'entailment']
#  ['two women play basketball.'
#   'a hockey goalkeeper and two other players are in front of the goal, with the puck in the foreground.'
#   'contradiction']]
# size of set: 43697
# 25715
# 25725
# 25735
# 25745
# 25755
# 25765
# 25775
# 25785
# 25795
# 25805
# Successful augmented objects, bad examples: 25805 1740
# Done in 42.74
# 5 random saved objects:
# [['Men watch TV.'
#   'two men are looking down at a building from a cherry picker.'
#   'contradiction']
#  ['the boy snuggles up against the plate.'
#   'a young man presses his face to his plate with food.' 'entailment']
#  ['woman receives a bouquet from her husband.'
#   'a woman about to be flooded in a flower shop outdoors.'
#   'contradiction']
#  ['the baby is swimming.' 'child with a green bucket on the beach.'
#   'contradiction']
#  ['big dog runs through red and white poles'
#   'black and white dog runs through red and white poles' 'neutral']]
# size of set: 43803
# 25815
# 25825
# 25835
# 25845
# 25855
# 25865
# 25875
# 25885
# 25895
# 25905
# Successful augmented objects, bad examples: 25905 1751
# Done in 42.45
# 5 random saved objects:
# [['the seller climbs the mountain.'
#   'a street vendor selling skewers is standing with his hands on his hips.'
#   'contradiction']
#  ['two dogs are fighting for a bone.'
#   'a tanned dog is fighting another tanned dog on gravel while someone is standing on a narbi.'
#   'neutral']
#  ['young woman draws a sharpie' 'young girl draws with marker'
#   'entailment']
#  ['two asians sit on the pavement'
#   'two Asian men are sitting on the pavement with their goods next to them.'
#   'entailment']
#  ['man in white sits on a bicycle.'
#   'A man dressed in a white suit with a red cowboy hat rides a bicycle.'
#   'entailment']]
# size of set: 43914
# 25915
# 25915
# 25925
# 25935
# 25945
# 25955
# 25965
# 25975
# 25975
# 25985
# 25995
# 26005
# Successful augmented objects, bad examples: 26005 1760
# Done in 44.00
# 5 random saved objects:
# [['the girl on skis is skiing.' 'girl is skiing during the holidays.'
#   'entailment']
#  ['there are two people in the pool.'
#   'A man holds a blond child in the pool.' 'entailment']
#  ['tourists hike through the forest.'
#   'vacationers are sitting at the very edge of the water.'
#   'contradiction']
#  ['child stroking a chick'
#   'a group of people in white shirts with a red handkerchief around their neck leaves the stadium, and two men are looking at something with a cup in their hand.'
#   'contradiction']
#  ['A woman is sitting next to a dog.'
#   'an elderly gray-haired lady and a bulldog are sitting on a stump.'
#   'neutral']]
# size of set: 44023
# 26015
# 26025
# 26035
# 26045
# 26055
# 26065
# 26075
# 26085
# 26095
# 26095
# 26105
# Successful augmented objects, bad examples: 26105 1776
# Done in 48.42
# 5 random saved objects:
# [['There are people who are watching something.'
#   'big skateboard skateboard with a couple of people in the background'
#   'entailment']
#  ['two guys are praying.'
#   'two guys kneel to the ground, making a hand gesture in the sky.'
#   'neutral']
#  ['a man is a woman who talks to herself.'
#   'a man with a cigarette is talking to a woman with a cigarette.'
#   'contradiction']
#  ['children play outside'
#   'Children play on a slide, one with a white shirt and blue jeans.'
#   'entailment']
#  ['children on the road play in the trash.'
#   'two children on the beach play in the sand like a tide.'
#   'contradiction']]
# size of set: 44139
# 26115
# 26125
# 26135
# 26145
# 26155
# 26165
# 26175
# 26185
# 26195
# 26205
# Successful augmented objects, bad examples: 26205 1786
# Done in 44.29
# 5 random saved objects:
# [['a man sings on stage.'
#   'a man in a blue helmet rides in the dirt on his bike.' 'contradiction']
#  ['lady wears an orange jacket.'
#   'a lady in an orange jacket is holding a walkie-talkie, while another lady in a light green jacket is standing next to her, looking at something in her hand and holding a cane.'
#   'entailment']
#  ['A woman is enjoying a concert.'
#   'A woman is drinking beer watching an open-air concert.' 'neutral']
#  ['two people are walking in Walmart.'
#   'two women are looking at a shopping list when they are stopped at the end of the aisle at the target.'
#   'contradiction']
#  ['woman on an airplane'
#   'A woman sings into a microphone, and two men accompany her on the keyboard and guitar.'
#   'contradiction']]
# size of set: 44249
# 26215
# 26225
# 26235
# 26245
# 26255
# 26265
# 26275
# 26285
# 26285
# 26295
# 26305
# Successful augmented objects, bad examples: 26305 1794
# Done in 43.64
# 5 random saved objects:
# [['The gladiator is preparing to meet his opponent.'
#   'a guy with a sword and traditional combat gear is preparing for battle.'
#   'neutral']
#  ['a bearded man in a blue jacket goes shopping.'
#   'A bearded man in a blue jacket was walking along the street.'
#   'neutral']
#  ['The man and his boss are having lunch.'
#   'one person leaves the four-door blue building, and the other enters it.'
#   'contradiction']
#  ['the building was demolished to build a new hospital.'
#   'The excavator is on top of a pile of rubble from a destroyed building.'
#   'neutral']
#  ['woman runs away from the police.'
#   'A woman is talking with two police officers in yellow jackets at an outdoor event.'
#   'contradiction']]
# size of set: 44357
# 26315
# 26325
# 26335
# 26345
# 26355
# 26365
# 26375
# 26385
# 26395
# 26405
# Successful augmented objects, bad examples: 26405 1802
# Done in 45.05
# 5 random saved objects:
# [['The girl draws only with a black pen.'
#   'girl draws with crayons and pencils.' 'contradiction']
#  ['people compete in a race.' '5k competitors start the competition.'
#   'neutral']
#  ['bungee jumping people'
#   'a group of people in working clothes goes out into the street, and witnesses watch.'
#   'contradiction']
#  ['there is a black t-shirt.'
#   'a man in a black T-shirt with adidas inscription in front and a woman in a white T-shirt with a silver bracelet on his left wrist are sitting next to a bicycle on the ground in the park and eating ice cream while people enjoy themselves around them'
#   'entailment']
#  ['woman at a flea market.'
#   'lady with a handbag looks at goods at a flea market.' 'entailment']]
# size of set: 44465
# 26415
# 26425
# 26435
# 26435
# 26445
# 26455
# 26465
# 26475
# 26485
# 26495
# 26505
# Successful augmented objects, bad examples: 26505 1812
# Done in 45.65
# 5 random saved objects:
# [['man is waiting with his computer.'
#   'A bearded man in a black T-shirt is sitting in front of a table with a computer.'
#   'entailment']
#  ['the boys are at the vending machines.'
#   'two boys are standing in front of vending machines.' 'entailment']
#  ['the chef cuts onions when preparing food.'
#   'chef enjoying a meal while in contemplation.' 'contradiction']
#  ['There are people who eat.'
#   'two men are working on their knees in front of the building.'
#   'contradiction']
#  ['Nancy looked at the paintings on the wall.'
#   'girl looking at some pictures on the wall.' 'entailment']]
# size of set: 44575
# 26515
# 26515
# 26525
# 26535
# 26545
# 26555
# 26555
# 26565
# 26575
# 26585
# 26595
# 26605
# Successful augmented objects, bad examples: 26605 1819
# Done in 44.83
# 5 random saved objects:
# [['policeman shines a flashlight in a dark window.'
#   'A young oriental woman in jeans, a blue jacket and a white shirt stands on the beach with a camera or mobile phone, covering the sun from her eyes with one hand.'
#   'contradiction']
#  ['male athlete.'
#   'a male athlete in a white shirt and white pants runs past the crowd holding a golden torch.'
#   'entailment']
#  ['the person in the picture is the man.'
#   'an oriental woman picks up a fruit tray and smiles, surrounded by many such fruit trays in a colorful display case.'
#   'contradiction']
#  ['the race is passing' 'The start of the bike race passes by the crowd.'
#   'entailment']
#  ['The man creating Milnor for Odin.'
#   'A man holds a hammer and a piece of hot iron in one hand.'
#   'contradiction']]
# size of set: 44682
# 26615
# 26625
# 26635
# 26645
# 26655
# 26665
# 26675
# 26675
# 26675
# 26685
# 26695
# 26705
# Successful augmented objects, bad examples: 26705 1833
# Done in 47.06
# 5 random saved objects:
# [['The boy is looking for his parents in the local food market.'
#   'A boy standing in a market looking at vegetables and fruits.'
#   'neutral']
#  ['a man stands next to a boy.'
#   'A man in a hat and tennis shoes sits on a granite ledge next to the boy who took off his tennis shoes.'
#   'entailment']
#  ['kids are sleeping' 'children play on a carousel on a cold day.'
#   'neutral']
#  ['girls sit down while sending a message.'
#   'blonde girl sitting in a yellow texting chair.' 'entailment']
#  ['two women at the computer are looking for job listings'
#   'a woman sits at a desktop computer, and a woman standing next to her points to something on the screen.'
#   'neutral']]
# size of set: 44796
# 26715
# 26725
# 26735
# 26745
# 26755
# 26765
# 26775
# 26785
# 26795
# 26805
# Successful augmented objects, bad examples: 26805 1844
# Done in 45.50
# 5 random saved objects:
# [['A karate student with a yellow belt is fighting a student with a white belt.'
#   'a boy dressed in karate and dressed in a yellow belt is ready to defend himself in the gym.'
#   'neutral']
#  ['The builder is drilling in the ground.'
#   'A man in a black jacket is talking into the microphone.'
#   'contradiction']
#  ['a pot under a person’s foot' 'A woman puts the dishes in the closet.'
#   'contradiction']
#  ['people posing for a picture.'
#   'An elderly woman and a young couple are standing on the sidewalk, posing to take a picture.'
#   'entailment']
#  ['dog is sleeping'
#   'brown-white dog runs near a wooden fence with a tennis ball in his mouth.'
#   'contradiction']]
# size of set: 44907
# 26815
# 26825
# 26835
# 26845
# 26855
# 26865
# 26875
# 26885
# 26895
# 26905
# Successful augmented objects, bad examples: 26905 1852
# Done in 45.54
# 5 random saved objects:
# [['man inside.' 'one person in a room does a handstand during the day.'
#   'entailment']
#  ['men are going to a party'
#   'a group of young people drank drinks sitting at a table in a restaurant.'
#   'neutral']
#  ['The boy does a terrific stunt on his skateboard, wearing a happy red shirt.'
#   'A boy in a red shirt rides on a skateboard.' 'neutral']
#  ['two men are fighting for the keyboard'
#   'A man in a white shirt is typing at his desk, near a window and a black chair.'
#   'contradiction']
#  ['women talk to each other.'
#   'two oriental women in a kimono are sitting under an umbrella on concrete seats.'
#   'neutral']]
# size of set: 45015
# 26915
# 26925
# 26935
# 26945
# 26955
# 26965
# 26965
# 26975
# 26985
# 26995
# 27005
# Successful augmented objects, bad examples: 27005 1863
# Done in 45.66
# 5 random saved objects:
# [['children watch TV.'
#   'two boys have lunch at McDonalds in an open area surrounded by many other people.'
#   'contradiction']
#  ['two karate girls are fighting.' 'two young girls in a karate match'
#   'entailment']
#  ['woman on the way to her car.'
#   'Woman in a pink shirt in the parking lot.' 'neutral']
#  ['man stands in front of a bowling alley.'
#   'a guy dressed in all black on a bowling alley stands in front of an alley with a black bowling ball.'
#   'entailment']
#  ['person performing maintenance.'
#   'bmx rider sitting on a concrete ledge fixing his wheel in a skate park.'
#   'entailment']]
# size of set: 45126
# 27015
# 27025
# 27035
# 27045
# 27055
# 27065
# 27075
# 27085
# 27095
# 27105
# Successful augmented objects, bad examples: 27105 1872
# Done in 43.16
# 5 random saved objects:
# [['Britsits actors outside.'
#   'British actors in the park, including an actor dressed as news feed.'
#   'entailment']
#  ['male workers at lunch break'
#   'three male workers were digging and rebuilding the sidewalk.'
#   'contradiction']
#  ['a woman shows off her breasts.'
#   'A woman, as a rule, demonstrates goods.' 'contradiction']
#  ['two people enjoy a steak inside.'
#   'two people are smiling, sitting on chairs in the yard.'
#   'contradiction']
#  ['dogs on training.' 'the muzzle of the white dogs runs.' 'neutral']]
# size of set: 45235
# 27115
# 27125
# 27135
# 27145
# 27155
# 27165
# 27175
# 27185
# 27195
# 27205
# Successful augmented objects, bad examples: 27205 1881
# Done in 45.26
# 5 random saved objects:
# [['three people by the river'
#   'three people stand in front of the river near the city, and one throws something at him.'
#   'entailment']
#  ['men builders'
#   'Two workers in helmets and life jackets are standing near the yellow concrete block.'
#   'neutral']
#  ['A man is fishing in a small boat.'
#   'A man fishing on a small pier when the sun sets over a pond.'
#   'neutral']
#  ['many men in the competition.'
#   'a lot of guys compete in strong men competitions.' 'entailment']
#  ['two friends in handmade scarves posed for a picture near the store.'
#   'two Africans in red and blue shawls posing for a picture near the hairdresser.'
#   'neutral']]
# size of set: 45344
# 27215
# 27225
# 27235
# 27245
# 27255
# 27265
# 27275
# 27285
# 27295
# 27305
# Successful augmented objects, bad examples: 27305 1894
# Done in 43.52
# 5 random saved objects:
# [['three - scuba diving.' 'three people go scuba diving.' 'entailment']
#  ['tram outside.'
#   'the tram moves along a narrow road, while a group of people gather at the foot of the hill.'
#   'entailment']
#  ['man and woman are going to a funeral'
#   'a man and a woman in black clothes are looking at the camera held by women as they climb the stone stairs and stone wall in the forest.'
#   'neutral']
#  ['Two men work in the pit.'
#   'Two men are working on repairing a hole in a building, being suspended from an elevator.'
#   'neutral']
#  ['an old dog is waiting for his master to feed him.'
#   'four young puppies snuggling together in the middle of the blanket.'
#   'contradiction']]
# size of set: 45457
# 27315
# 27325
# 27335
# 27345
# 27355
# 27365
# 27375
# 27375
# 27385
# 27395
# 27405
# Successful augmented objects, bad examples: 27405 1906
# Done in 44.23
# 5 random saved objects:
# [['three pigs eat lunch'
#   'three women in black coats are talking and laughing in an art gallery.'
#   'contradiction']
#  ['football player from oklahoma not worth it'
#   'Oklahoma football player stands' 'contradiction']
#  ['A man is wearing a suit and tie.'
#   'An elderly man with tattoos and biker regalia lingers on a city street.'
#   'contradiction']
#  ['A woman in a pink shirt and blue jeans sits at home on the couch.'
#   'A woman in pink shit and blue jeans is walking along a busy street, holding a cup of coffee.'
#   'contradiction']
#  ['A man is walking his dog.'
#   'many different people shop in the indoor market.' 'contradiction']]
# size of set: 45569
# 27415
# 27425
# 27435
# 27445
# 27455
# 27465
# 27475
# 27485
# 27495
# 27505
# Successful augmented objects, bad examples: 27505 1915
# Done in 44.27
# 5 random saved objects:
# [['birds eat bees'
#   'a woman with reddish hair is talking to an old man by the water and near a bench.'
#   'contradiction']
#  ['three men outside'
#   'Three eastern men ride a moped in a city with many people.'
#   'entailment']
#  ['The boy is holding a stick figure.'
#   'A boy in a green and blue shirt sits inside an earth moving machine.'
#   'neutral']
#  ['there was a couple dancing among others.'
#   'a man and a woman are dancing, and an elderly woman is standing nearby; other seated women look in the background.'
#   'neutral']
#  ['football players play in a tournament'
#   'football players go on the field.' 'neutral']]
# size of set: 45678
# 27515
# 27525
# 27535
# 27545
# 27555
# 27565
# 27565
# 27565
# 27575
# 27585
# 27595
# 27605
# Successful augmented objects, bad examples: 27605 1928
# Done in 42.99
# 5 random saved objects:
# [['young people are preparing sandwiches for dinner.'
#   'young people in yellow shirts cook colorful food.' 'neutral']
#  ['girl kills and eats cows.'
#   'A little girl leans forward into a cage of cows.' 'contradiction']
#  ['musician on stilts.'
#   'a street musician standing on stilts plays a tube on the street before painting kissing people.'
#   'entailment']
#  ['girl with red hair lies on a towel on the beach.'
#   'girl with bright red hair and black clothes posing on a tree trunk.'
#   'contradiction']
#  ['girls go in for sports' 'group of girls playing field hockey.'
#   'entailment']]
# size of set: 45791
# 27615
# 27625
# 27635
# 27635
# 27645
# 27655
# 27665
# 27675
# 27685
# 27695
# 27705
# Successful augmented objects, bad examples: 27705 1938
# Done in 43.22
# 5 random saved objects:
# [['man inside.' 'woman in a hat sitting in the water in the desert.'
#   'contradiction']
#  ['the man who fell in the grass was still able to hit, returning the pitch.'
#   'Woman plays tennis sitting in the grass.' 'neutral']
#  ['people are sleeping.'
#   'Many people watch a person in yellow inflate balloons with animals.'
#   'contradiction']
#  ['a man with children is playing' 'A man plays a musical instrument.'
#   'contradiction']
#  ['woman bakes a birthday cake in the forest.'
#   'a woman in a flowing blue robe with a white wave pattern is dancing in front of a large brick building with other dancers similarly dressed in the background.'
#   'contradiction']]
# size of set: 45901
# 27705
# Successful augmented objects, bad examples: 27705 1939
# Done in 0.54
# 5 random saved objects:
# [['man smokes inside.'
#   'a man stands in the kitchen, holds a rolling pin and smokes a cigarette.'
#   'entailment']
#  ['the liquid begins to hiss and soon fill the room with clouds of orange smoke.'
#   'a girl pours liquid into a glass while another girl is looking.'
#   'neutral']
#  ['two lovers on the beach'
#   'young boy runs after a young girl on the beach.' 'neutral']
#  ['young man celebrates at the bar.'
#   'A young man celebrates while playing pool in a bar.' 'entailment']
#  ['young girl throws a ball at a senior boy with a bat near a wooden gate'
#   'a girl in a red top serves a cricket ball to a boy in a yellow shirt, who is standing in front of a wicket with a bat.'
#   'neutral']]
# size of set: 45902
# 27715
# 27715
# 27725
# 27735
# 27745
# 27755
# 27765
# 27775
# 27785
# 27795
# 27805
# Successful augmented objects, bad examples: 27805 1952
# Done in 44.89
# 5 random saved objects:
# [['children watch a cyclist on a tightrope.'
#   'children watch the performance of a cyclist on a tightrope.'
#   'entailment']
#  ['In the photo there is a small child who is eating.'
#   'elderly man is having lunch from a bowl.' 'contradiction']
#  ['young woman watching tv.'
#   'a young woman uses a whisk to mix the contents of a large pyrex cup.'
#   'contradiction']
#  ['the seller is dressed in uniform.'
#   'a salesman in a red khaki shirt and panties hands someone some Italian ice from his bada bing cart.'
#   'neutral']
#  ['people inside.'
#   'a group of people stands outside, staring at different people lying on the ground.'
#   'contradiction']]
# size of set: 46015
# 27815
# 27825
# 27835
# 27845
# 27855
# 27865
# 27875
# 27885
# 27885
# 27895
# 27905
# Successful augmented objects, bad examples: 27905 1960
# Done in 45.78
# 5 random saved objects:
# [['There are people participating in swimming competitions.'
#   'two girls are swimming in the pool.' 'neutral']
#  ['man looking for his water bottle'
#   'a male cyclist is trying to get something out of a backpack on a busy street.'
#   'neutral']
#  ['cars go in cold weather' 'dirty jeep rides through the forest.'
#   'neutral']
#  ['boy and girl hold hands'
#   'A girl dressed in a navy coat and a boy in white robes hold hands, climbing the stone steps.'
#   'entailment']
#  ['a man with glasses high.' 'a man with glasses engaged in climbing.'
#   'neutral']]
# size of set: 46123
# 27905
# Successful augmented objects, bad examples: 27905 1961
# Done in 0.42
# 5 random saved objects:
# [['guitarist and drummer play'
#   'a guitarist in a Hawaiian shirt plays on stage with a drummer behind him.'
#   'entailment']
#  ['a man performs thundering activities.' 'Asian man shaves his face.'
#   'entailment']
#  ['dog on the beach' 'dog walks along the beach' 'entailment']
#  ['two young children read a stone tablet.'
#   'two young children sitting on the ground with a stone tablet.'
#   'neutral']
#  ['two ladies are laughing'
#   'laughing two bald ladies in red dresses and matching jewelry.'
#   'entailment']]
# size of set: 46124
# 27915
# 27925
# 27935
# 27945
# 27955
# 27965
# 27975
# 27985
# 27995
# 28005
# Successful augmented objects, bad examples: 28005 1972
# Done in 46.53
# 5 random saved objects:
# [['dogs in the park.' 'two dogs run for a stick.' 'neutral']
#  ['A man is jumping in the hills with his all-terrain vehicle.'
#   'man jumping with an all-terrain vehicle' 'neutral']
#  ['Man with a zipper.' 'black man hands someone his phone.'
#   'contradiction']
#  ['the ceremony for life is now over.' 'people leave the ceremony.'
#   'neutral']
#  ['sunny day' 'farm workers pick celery on a bright sunny day.'
#   'entailment']]
# size of set: 46235
# 28005
# Successful augmented objects, bad examples: 28005 1973
# Done in 0.33
# 5 random saved objects:
# [['kids are sleeping.'
#   'A group of children stands together, playing on tambourines of different colors.'
#   'contradiction']
#  ['A man exits a building in a city in ruins.'
#   'woman goes out of a building in an asian city.' 'contradiction']
#  ['two men in a church'
#   'Mother and her daughter love to ride a carousel.' 'contradiction']
#  ['There is a motorcycle race.'
#   'biker rides a motorcycle on a race track' 'neutral']
#  ['There are people standing on the stage.'
#   'people perform on stage in front of a crowd.' 'entailment']]
# size of set: 46236
# 28015
# 28025
# 28035
# 28045
# 28055
# 28065
# 28065
# 28075
# 28085
# 28095
# 28105
# Successful augmented objects, bad examples: 28105 1989
# Done in 48.62
# 5 random saved objects:
# [['heavy man in black gloves.'
#   'skinny guy with long curly hair and glasses wearing white gloves when something introduces into a bottle'
#   'contradiction']
#  ['some people try to restrain an attacker.'
#   'people on two balconies and a person climbing a pipe to the lower balcony pour liquid.'
#   'neutral']
#  ['ladies are standing next to the children'
#   'two ladies in jeans stood in front of three young children with blond hair.'
#   'entailment']
#  ['A man is fixing a fan on a computer.'
#   'A man in a business casual dress puts on a headlamp and starts repairing electronic equipment.'
#   'neutral']
#  ['woman repairing a male car.'
#   'A man is fixing a bike, and a woman is looking.' 'contradiction']]
# size of set: 46352
# 28115
# 28125
# 28135
# 28145
# 28155
# 28165
# 28175
# 28185
# 28195
# 28205
# Successful augmented objects, bad examples: 28205 1998
# Done in 43.61
# 5 random saved objects:
# [['kayak yellow.' 'participant in kayaking competitions.' 'neutral']
#  ['a group of men is going to fight'
#   'it seems that two men are talking, standing in front of the back of the truck and behind a metal object, while four people are standing around them.'
#   'neutral']
#  ['to play football' 'A man plays the drums at a concert.'
#   'contradiction']
#  ['A woman is waiting for her boyfriend.'
#   'A woman in a purple shirt stands on a city street with arms crossed.'
#   'neutral']
#  ['some people drive in a car.'
#   'The vehicle carries a crowd of people who are sitting and standing.'
#   'entailment']]
# size of set: 46461
# 28215
# 28225
# 28235
# 28245
# 28255
# 28265
# 28275
# 28285
# 28295
# 28305
# Successful augmented objects, bad examples: 28305 2001
# Done in 41.60
# 5 random saved objects:
# [['men in the game.' 'two male adversaries in a football match.'
#   'entailment']
#  ['the child is playing.' 'child walks in the ocean.' 'neutral']
#  ['woman wearing a green coat'
#   'a woman in a blue coat and boots drags a small child in the snow on a sled'
#   'contradiction']
#  ['people eat.' 'people try food from a local bakery at a local diner.'
#   'entailment']
#  ['girl playing with bubbles' 'girl blowing a bubble from her mouth.'
#   'entailment']]
# size of set: 46564
# 28315
# 28325
# 28335
# 28345
# 28355
# 28365
# 28375
# 28375
# 28375
# 28385
# 28395
# 28405
# Successful augmented objects, bad examples: 28405 2012
# Done in 46.11
# 5 random saved objects:
# [['woman in suit'
#   'young woman in a red suit with sequins and a feather stands on the sidewalk.'
#   'neutral']
#  ['someone on a walk for work in the city.'
#   'a pedestrian walking under a beautiful old tree without leaves, but with green grass underfoot, with the building peaks shown below.'
#   'neutral']
#  ['two boys ride their toy car along the road.'
#   'two boys are playing on a toy car.' 'neutral']
#  ['little girl plays in the playground.'
#   'a bird&#39;s eye lens captures a young girl with dark hair in a playground from a bird&#39;s eye view.'
#   'entailment']
#  ['a man acts with his group.'
#   'man in a brown shirt and jeans playing the guitar and singing.'
#   'neutral']]
# size of set: 46675
# 28415
# 28425
# 28435
# 28445
# 28455
# 28465
# 28475
# 28485
# 28495
# 28495
# 28505
# Successful augmented objects, bad examples: 28505 2018
# Done in 45.03
# 5 random saved objects:
# [['woman leads a group of students.'
#   'a woman holds a pen and looks down, while five people look at.'
#   'neutral']
#  ['the player with the ball overtakes the players of the other team and scores a winning point'
#   'one player caught a pass, while two players from the opposing team try to mark him while he is on the ground.'
#   'neutral']
#  ['six women are walking down the street.'
#   '6 friends are walking down the street.' 'neutral']
#  ['children play a board game in the kitchen.'
#   'five young people, four boys and one girl, gathered in the kitchen.'
#   'neutral']
#  ['A man runs across the field.'
#   'a man with a bandage on his finger was climbing, as others were watching.'
#   'contradiction']]
# size of set: 46781
# 28515
# 28515
# 28525
# 28535
# 28545
# 28555
# 28565
# 28575
# 28585
# 28595
# 28605
# Successful augmented objects, bad examples: 28605 2027
# Done in 45.30
# 5 random saved objects:
# [['Hipster has brown hair.'
#   'Gorgeous, blond hipster walks past a man with car problems.'
#   'contradiction']
#  ['A man uses his cell phone to call a taxi.'
#   'A man in a hat sits at a bus stop on a laptop.' 'contradiction']
#  ['young man plays billiards.'
#   'a young man in a red shirt prepares to hit 8 balls on a pool table.'
#   'entailment']
#  ['group plays video games'
#   'a small group of people play video games in someone&#39;s living room.'
#   'entailment']
#  ['military in place' 'military personnel are patrolling the area.'
#   'entailment']]
# size of set: 46890
# 28615
# 28615
# 28625
# 28635
# 28645
# 28655
# 28665
# 28665
# 28675
# 28675
# 28685
# 28695
# 28695
# 28705
# Successful augmented objects, bad examples: 28705 2042
# Done in 47.37
# 5 random saved objects:
# [['group of people together near the surface.'
#   'four people on the street together near the table.' 'entailment']
#  ['men are playing.' 'seven people play rugby.' 'entailment']
#  ['on the baseball cap is the logo of her favorite sports team.'
#   'two women in skirts and baseball caps pass another woman in a skirt on the street.'
#   'neutral']
#  ['A boy blows out candles on a birthday cake.'
#   'large transparent bears filled with various kinds of sweets.'
#   'contradiction']
#  ['the singer is on stage in front of an audience during a concert.'
#   'The lead singer of the group is holding a microphone and both hands are in the air on a purple background.'
#   'neutral']]
# size of set: 47005
# 28705
# Successful augmented objects, bad examples: 28705 2043
# Done in 0.32
# 5 random saved objects:
# [['a man and a woman in the kitchen with another woman who is cooking something to eat.'
#   'A man and a woman in black sit at the kitchen table and look like a woman in a red T-shirt dough on a cutting board.'
#   'entailment']
#  ['man is resting after practicing martial arts.'
#   'a man in a suit doing martial arts.' 'contradiction']
#  ['A building site is building a boat.'
#   'construction site tears wall with graffiti.' 'contradiction']
#  ['four people are walking on the street.'
#   'four people in orange clothes are walking along the street.'
#   'entailment']
#  ['Dog enjoys wildlife in the creek.' 'white dog in the creek.' 'neutral']]
# size of set: 47006
# 28715
# 28725
# 28735
# 28735
# 28745
# 28755
# 28765
# 28775
# 28775
# 28785
# 28795
# 28805
# Successful augmented objects, bad examples: 28805 2051
# Done in 44.39
# 5 random saved objects:
# [['there is a dog sitting resting'
#   'a tanned dog bites a broom, moving on a brick floor.' 'contradiction']
#  ['the dog takes the stick to its owner.'
#   'black and white dog with a stick in his mouth, standing on a hill.'
#   'neutral']
#  ['two people are sitting on the street.'
#   'a man and a woman get into a car and look at the camera opposite.'
#   'entailment']
#  ['some people eat.' 'a group of people are eating.' 'entailment']
#  ['Two people are preparing to collect trash on the beach.'
#   'two people are holding a trash bag, about to collect trash, and a third is looking at the bag with the camera.'
#   'neutral']]
# size of set: 47114
# 28815
# 28825
# 28835
# 28845
# 28855
# 28865
# 28875
# 28885
# 28895
# 28895
# 28895
# 28905
# Successful augmented objects, bad examples: 28905 2067
# Done in 45.42
# 5 random saved objects:
# [['girl hands out samples of her first job'
#   'Girl Handing Out Starbucks Samples At A Street Fair.' 'neutral']
#  ['the girl is sleeping.' 'young blonde plays with toys.' 'contradiction']
#  ['The man returns the collar to its rightful owner.'
#   'A man holds a collar of a young Rottweiler.' 'neutral']
#  ['An Asian man working in a cafe has a foam cup.'
#   'An Asian man in a blue apron looks into his Styrofoam coffee cup.'
#   'neutral']
#  ['Climber in the air.'
#   'a rock climber hangs on a ledge while others look further.'
#   'entailment']]
# size of set: 47230
# 28915
# 28925
# 28935
# 28945
# 28955
# 28965
# 28975
# 28985
# 28995
# 29005
# Successful augmented objects, bad examples: 29005 2074
# Done in 44.55
# 5 random saved objects:
# [['two boys play with their dogs on the beach.'
#   'two boys are playing with two dogs near the ocean.' 'neutral']
#  ['There are bright lights in the shop windows.'
#   'A man in a white shirt and dark pants leaning against a wall with two display cases that have a bright light.'
#   'entailment']
#  ['it is bright.' 'Neon gas station sign at night.' 'neutral']
#  ['Jim is preparing for the gymnastics olympiad.'
#   'a man doing a backflip in a black shirt and red tracksuits.' 'neutral']
#  ['crowd of men running triathlon'
#   'in a race a crowd of men running with paper numbers on their shirts.'
#   'neutral']]
# size of set: 47337
# 29015
# 29025
# 29035
# 29045
# 29055
# 29065
# 29075
# 29085
# 29095
# 29105
# Successful augmented objects, bad examples: 29105 2087
# Done in 41.81
# 5 random saved objects:
# [['some children roller skate around the cones.'
#   'two children participate in a game of hockey.' 'contradiction']
#  ['beach class reunion'
#   'a small crowd stood on the ocean in the evening.' 'neutral']
#  ['A man is riding a train.'
#   'A man dressed in a light shirt and jumpsuit is trying to work on a train locomotive.'
#   'contradiction']
#  ['A man was waiting for his wife and children near the store.'
#   'A man stands at the top of the stairs near the Costco store.'
#   'neutral']
#  ['the girl is sitting in a brand new boat.'
#   'Negro boy in a makeshift boat on the water.' 'contradiction']]
# size of set: 47450
# 29115
# 29125
# 29135
# 29145
# 29155
# 29165
# 29175
# 29185
# 29195
# 29205
# Successful augmented objects, bad examples: 29205 2098
# Done in 43.49
# 5 random saved objects:
# [['a border collie jumped on an obstacle for a dexterity test.'
#   'border collie jumping over an obstacle.' 'neutral']
#  ['young people are sitting at the table.'
#   'young people are sitting at the restaurant table, smiling.'
#   'entailment']
#  ['The sign hangs on the side of the store in the city center.'
#   'Sign on a store in and urban surroundings.' 'entailment']
#  ['young lady shows her hand.'
#   'a young lady either shows off her manicure or hitchhikes.'
#   'entailment']
#  ['two people are waiting for their friend to show.'
#   'next to a white and blue van with a black and green stripe are two people in bright green shirts and dark trousers.'
#   'neutral']]
# size of set: 47561
# 29215
# 29225
# 29235
# 29245
# 29255
# 29265
# 29275
# 29285
# 29295
# 29305
# Successful augmented objects, bad examples: 29305 2106
# Done in 43.76
# 5 random saved objects:
# [['A man leads a piece of equipment at the facility.'
#   'man in a yellow car in a dirty field at an event' 'entailment']
#  ['child holds pants'
#   'the child is holding a dress that another child is looking at.'
#   'contradiction']
#  ['the person who was shot in the leg is playing a game.'
#   'A man with one leg plays volleyball.' 'neutral']
#  ['the girl is truly a man and is 8 feet tall.'
#   'female softball player slides sharply into the plate as the baseman stands, ready to catch the ball.'
#   'contradiction']
#  ['There are some animals.' 'two black dogs.' 'entailment']]
# size of set: 47669
# 29315
# 29325
# 29335
# 29345
# 29355
# 29365
# 29375
# 29385
# 29395
# 29405
# Successful augmented objects, bad examples: 29405 2115
# Done in 44.61
# 5 random saved objects:
# [['boy throws firecrackers at firefighters when they unload their truck at the fire station'
#   'a little boy stands in front of a bright red building.' 'neutral']
#  ['Four people are going to work who take lace in a slightly wooded area.'
#   'four people walked toward a large construction tower in a wooded area.'
#   'neutral']
#  ['workers finish their work.'
#   'Factory workers are steadily completing their work.' 'entailment']
#  ['A man goes to the bar.'
#   'A man walked along the sidewalk under a green awning.' 'neutral']
#  ['woman is reading.'
#   'A woman in a brown jacket is reading a book while traveling by public transport.'
#   'entailment']]
# size of set: 47778
# 29415
# 29425
# 29435
# 29445
# 29455
# 29465
# 29475
# 29485
# 29495
# 29505
# Successful augmented objects, bad examples: 29505 2126
# Done in 47.02
# 5 random saved objects:
# [['children in the bedroom.' 'four children throw a pillow fight'
#   'neutral']
#  ['A man is looking through a glass door.'
#   'in front of the glass doors is a man with a blue spot and a pink spot.'
#   'entailment']
#  ['a man hanging a child over water.'
#   'A man holds a child over the pool.' 'entailment']
#  ['they are dancing in a competition.'
#   'Four couples perform dance exercises in bright green and white costumes.'
#   'neutral']
#  ['woman having fun'
#   'A woman in a green shirt is reading a doctor. Seuss book for three children.'
#   'neutral']]
# size of set: 47889
# 29505
# Successful augmented objects, bad examples: 29505 2127
# Done in 0.30
# 5 random saved objects:
# [['the goal of the cowgirl is the calf.'
#   'a cowgirl lasses a young white calf from the back of her brown horse.'
#   'entailment']
#  ['people keep safety bars on a crowded bus.'
#   'people are hanging on safety rails on a very crowded bus.'
#   'entailment']
#  ['woman puts on a mask to rob a bank.'
#   'a blond woman who sits outside in the grass, paints her face and looks in the mirror.'
#   'contradiction']
#  ['man is jumping in the air.'
#   'a man is jumping in the air in front of a coastal scene with water and mountains in the background.'
#   'entailment']
#  ['A fisherman stands on a balcony overlooking a dry, dusty street.'
#   'blond fisherman standing in the water, preparing his hook.'
#   'contradiction']]
# size of set: 47890
# 29505
# Successful augmented objects, bad examples: 29505 2128
# Done in 0.39
# 5 random saved objects:
# [['In July, a man on stage says something to the crowd.'
#   'a speaker at the 55th annual July celebration in the Delwood area broadcasts a message from the stage as others watch.'
#   'entailment']
#  ['the animal is jumping.'
#   'a white dog with orange ribbons jumps to see a countertop.'
#   'entailment']
#  ['African women dance and sing.'
#   'women in culture - a specific outfit, dancing and singing.' 'neutral']
#  ['woman stands looking at a tall billboard.'
#   'a man in a yellow shirt with a tall gray suitcase sits next to another man in a white shirt and gray pants, followed by a tall billboard for sunglasses and prescription glasses.'
#   'neutral']
#  ['black dog outside' 'black dog digging in the snow.' 'entailment']]
# size of set: 47891
# 29515
# 29525
# 29535
# 29545
# 29555
# 29565
# 29575
# 29575
# 29585
# 29595
# 29605
# Successful augmented objects, bad examples: 29605 2137
# Done in 44.03
# 5 random saved objects:
# [['man with a microphone'
#   'a guy sitting in a chair, dressed in black, with headphones and a microphone, might be getting ready to sing.'
#   'entailment']
#  ['people at the table.'
#   'people are sitting at a table with papers and a cup of coffee.'
#   'entailment']
#  ['A diverse group of children are listening to something loud.'
#   'Six young men, one African American, one Hispanic and other Caucasians, stand in front of the fence in the form of a chain link and wear various clothes, five of them hold their ears.'
#   'entailment']
#  ['the man is eating.'
#   'man is resting in a wooden basin with water when he eats fruit.'
#   'entailment']
#  ['woman wears a coat.'
#   'A woman in a red coat looks through an invisible sheet on the catwalk, and a man in a blue tie looks through his catwalk and plays the acoustic guitar.'
#   'entailment']]
# size of set: 48000
# 29615
# 29625
# 29635
# 29645
# 29655
# 29665
# 29675
# 29685
# 29695
# 29705
# Successful augmented objects, bad examples: 29705 2146
# Done in 44.23
# 5 random saved objects:
# [['girls inside.'
#   'two girls are sitting on the floor in the hallway on laptops.'
#   'entailment']
#  ['male breakdance.'
#   'A crowd is formed to watch a breakdance man outdoors.' 'entailment']
#  ['Young swimmers gather for a peppy conversation with their captain.'
#   'young swimmers gather for a peppy conversation.' 'neutral']
#  ['son and father make shelves' 'father and son make shelves together.'
#   'entailment']
#  ['girl with a broken leg on the beach.'
#   'Girl jumping on the beach near the Golden Gate Bridge.'
#   'contradiction']]
# size of set: 48109
# 29715
# 29715
# 29725
# 29725
# 29735
# 29745
# 29755
# 29765
# 29775
# 29785
# 29785
# 29795
# 29805
# Successful augmented objects, bad examples: 29805 2156
# Done in 44.18
# 5 random saved objects:
# [['woman collects something'
#   'young woman collects a wooden cupboard on the floor.' 'entailment']
#  ['A young girl rides a camel in the desert.'
#   'a young girl falls and cries in the desert.' 'contradiction']
#  ['The boy rides a hobby horse.'
#   'a woman in a black jacket and blue pants rides on his shoulder at a construction site.'
#   'contradiction']
#  ['the person in the photo does not wear hats'
#   'A man in a cowboy hat looks at the motorcycle with curiosity.'
#   'contradiction']
#  ['the cat purrs'
#   'Two people are standing at the door of the house in the snow.'
#   'contradiction']]
# size of set: 48219
# 29815
# 29825
# 29825
# 29835
# 29845
# 29855
# 29865
# 29875
# 29885
# 29895
# 29905
# Successful augmented objects, bad examples: 29905 2165
# Done in 44.31
# 5 random saved objects:
# [['gray is the man’s favorite color.'
#   'A man in a gray sweater plays darts next to a red curtain.' 'neutral']
#  ['lady is standing next to the dog.'
#   'A lady in a green blouse is holding a boy in a red shirt and blue jeans, standing next to a tall guy.'
#   'contradiction']
#  ['the baby may be sick.' 'The doctor checks the baby’s stomach.'
#   'neutral']
#  ['two men hugging on the street.' 'two men hugging on the street.'
#   'entailment']
#  ['man and woman share a newspaper in the park.'
#   'two women are sitting on a park bench and reading newspapers.'
#   'contradiction']]
# size of set: 48328
# 29915
# 29925
# 29935
# 29945
# 29955
# 29965
# 29975
# 29985
# 29995
# 30005
# Successful augmented objects, bad examples: 30005 2173
# Done in 40.62
# 5 random saved objects:
# [['girls are running down the street.'
#   'a group of women in pink dresses is walking along the street.'
#   'contradiction']
#  ['the dog’s mouth is closed.'
#   'Black and white dog with wide open mouth.' 'contradiction']
#  ['The man lost his watch in the urinal.'
#   'A man in khaki shorts and blue shirts kneels to take pictures on the street.'
#   'contradiction']
#  ['the dog is eating food.'
#   'tanned dog digs a hole on the edge of the sand.' 'contradiction']
#  ['dog outside.'
#   'Golden retriever looking at his reflection in the water next to the snow.'
#   'entailment']]
# size of set: 48436
# 30015
# 30025
# 30035
# 30045
# 30055
# 30055
# 30065
# 30075
# 30085
# 30095
# 30105
# Successful augmented objects, bad examples: 30105 2183
# Done in 48.42
# 5 random saved objects:
# [['there a woman walks listening to music on headphones.'
#   'A slender young Caucasian woman walks listening to music through her headphones and iPod during a bright sunny day.'
#   'entailment']
#  ['couple watching the sunset of the ocean.'
#   'couple sitting on a bench enjoying mountain view.' 'contradiction']
#  ['baby outside.' 'child on a plastic sled.' 'neutral']
#  ['A man swims in the ocean.'
#   'male musician plays the accordion in a leather jacket and hat on the boardwalk or pier.'
#   'contradiction']
#  ['a child in multi-colored google playing in the pool has a pink float.'
#   'child in multi-colored glasses plays in the pool.' 'neutral']]
# size of set: 48546
# 30115
# 30125
# 30135
# 30145
# 30155
# 30165
# 30165
# 30175
# 30185
# 30195
# 30205
# Successful augmented objects, bad examples: 30205 2194
# Done in 43.84
# 5 random saved objects:
# [['the crowd behind the fence watches as cyclists ride uphill and motorcycles ride behind them'
#   'The crowd behind the fence watches as cyclists ride along a hilly road with motorcycles behind them.'
#   'entailment']
#  ['skydiver sweats from nerves.'
#   'a paratrooper in a yellow parachute prepares to land.' 'neutral']
#  ['two people in opposing teams during a roller skate match.'
#   'A man in blue uniform on roller skates and a man in camouflage ice skating compete in the ring.'
#   'neutral']
#  ['man holds something' 'man in a blue shirt holding a camera equipment.'
#   'entailment']
#  ['mother tomato'
#   'a child watches her mom measure herself against a tomato holding a ruler.'
#   'contradiction']]
# size of set: 48657
# 30215
# 30225
# 30235
# 30245
# 30255
# 30265
# 30275
# 30285
# 30295
# 30305
# Successful augmented objects, bad examples: 30305 2202
# Done in 42.53
# 5 random saved objects:
# [['the band is going to play their favorite audience.'
#   'there is a group on stage whose members wear blue shades.' 'neutral']
#  ['streamers are big.'
#   'a woman and a man with tattoos on the top of both hands are having fun on the sidewalk with several stretch marks around them.'
#   'neutral']
#  ['little boy is training for golf.'
#   'little boy kicks the golf ball at the driving range.' 'neutral']
#  ['young man is sitting on a chair.'
#   'young man tries to hit his opponent in the head' 'contradiction']
#  ['the group practices its new poses.'
#   'people practicing their instrumental and musical skills gathered around the house.'
#   'contradiction']]
# size of set: 48765
# 30315
# 30325
# 30335
# 30345
# 30355
# 30355
# 30365
# 30375
# 30385
# 30395
# 30405
# Successful augmented objects, bad examples: 30405 2207
# Done in 44.73
# 5 random saved objects:
# [['gentleman farmer.'
#   'A gentleman with gray hair climbs the wooden steps on a cool day.'
#   'neutral']
#  ['children ride bicycles.' 'two children in the ruins of a building.'
#   'contradiction']
#  ['two cats are sleeping.' 'brown dog runs in the snow' 'contradiction']
#  ['people came to see the famous cowboys.'
#   'In this photo, people who look like a rodeo are sitting around the blue gate. The main attention is paid to a little boy who leans on the railing from behind the railing and reaches out in a gesture with a red-blue and a white-checked shirt, blue jeans and a belt with a large gold buckle.'
#   'neutral']
#  ['girl on a hike.' 'A girl stands on a path in a field with trees.'
#   'neutral']]
# size of set: 48870
# 30415
# 30425
# 30435
# 30445
# 30455
# 30465
# 30475
# 30485
# 30485
# 30495
# 30505
# Successful augmented objects, bad examples: 30505 2215
# Done in 44.74
# 5 random saved objects:
# [['people at lunch break from work'
#   'Here is an image of a man sitting on an island chatting with locals.'
#   'neutral']
#  ['man on the steps.'
#   'a man with a beard in a hood is walking along the concrete steps with a red bag, and a policeman is looking at the water, threatening to get on the steps.'
#   'entailment']
#  ['old black man is parachuting.'
#   'a young black man sits in an unfinished brick and mortar building, there is no glass in the large window on the left, the day comes, and the sun buries the room, he sits at a simple bench and table, holding two blue pens in his hands and reading from one of the two notebooks that lie on the table, he wears a yellow polo and shines blue shorts.'
#   'contradiction']
#  ['A man is wearing a white hockey mask.'
#   'a man wears a golden mask with pointed hair and a yellow shirt.'
#   'contradiction']
#  ['couple of farmers plowing a field'
#   'A woman in fur and a gentleman in a suit climb the snow after shopping.'
#   'contradiction']]
# size of set: 48978
# 30515
# 30525
# 30535
# 30545
# 30555
# 30555
# 30565
# 30575
# 30585
# 30595
# 30605
# Successful augmented objects, bad examples: 30605 2225
# Done in 44.84
# 5 random saved objects:
# [['A man sells fruit to customers.'
#   'A man in a red shirt sits by the fruits for sale.' 'neutral']
#  ['tall man flies' 'trick - a cyclist flies over onlookers.' 'neutral']
#  ['little boy in a helmet and holds a gun.'
#   'blond child in a helmet, glasses and binoculars holds a toy gun.'
#   'entailment']
#  ['yellow car stops for pedestrians when they cross the street on a sunny day'
#   'the yellow car stops for pedestrians when they cross the street on a sunny day.'
#   'entailment']
# ...
# 41665
# 41675
# 41685
# 41695
# 41705
# Successful augmented objects, bad examples: 41705 3442
# Done in 49.61
# 5 random saved objects:
# [['he is sitting in the house.'
#   'An elderly man in a turban sits on the ground, holding a large stone.'
#   'contradiction']
#  ['a boy stands on top of a hill.'
#   'a very young boy in a black jacket, jeans and tennis shoes keeps himself on top of a hill, waiting to go downstairs.'
#   'entailment']
#  ['people swim in the ocean'
#   'There are many people walking in a city that is worn out by buildings.'
#   'contradiction']
#  ['A white dog runs with one ear up.' 'in the ear of a dog' 'entailment']
#  ['A man is fishing on the river.'
#   'A man floats on a dirty river in a long boat.' 'neutral']]
# size of set: 61405
# 41715
# 41725
# 41735
# 41745
# 41755
# 41765
# 41775
# 41785
# 41795
# 41805
# Successful augmented objects, bad examples: 41805 3454
# Done in 45.42
# 5 random saved objects:
# [['old men'
#   'two men in green life jackets and white helmets are doing work near orange cones with white stripes.'
#   'neutral']
#  ['German shepherd on the street.'
#   'German shepherd digs a large hole in the sand.' 'entailment']
#  ['A woman in a blue hat wears a red sweatshirt.'
#   'A woman in a blue hat and gray sweater is sitting with a dark-haired female doctor, and she has a dropper in her hand.'
#   'contradiction']
#  ['A man is waiting for his car at the gate.'
#   'behind the black gate stands a man.' 'neutral']
#  ['women work together' 'two young women working on a project.'
#   'entailment']]
# size of set: 61517
# 41815
# 41825
# 41835
# 41845
# 41855
# 41855
# 41865
# 41875
# 41875
# 41885
# 41895
# 41905
# Successful augmented objects, bad examples: 41905 3462
# Done in 43.97
# 5 random saved objects:
# [['couple is sitting on the couch.'
#   'man and woman are training in the park.' 'contradiction']
#  ['girl is driving a taxi.'
#   'a girl with blond hair holds a bottle and wears a blue-green floral bikini on a boat.'
#   'contradiction']
#  ['parents scream about their children in football practice'
#   'parents in sun loungers watch their children practice football.'
#   'neutral']
#  ['Two men stand naked on a corn field.'
#   'two men, one in red uniform with white stripes and the other in white uniform, play football.'
#   'contradiction']
#  ['one old man sits alone.'
#   'young man and woman at the dinner table with food in front of them.'
#   'contradiction']]
# size of set: 61625
# 41915
# 41925
# 41935
# 41945
# 41955
# 41965
# 41965
# 41975
# 41985
# 41995
# 42005
# Successful augmented objects, bad examples: 42005 3474
# Done in 47.79
# 5 random saved objects:
# [['children play on a dirty mound.'
#   'two little boys are sitting on a lump of mud.' 'neutral']
#  ['A man on a motorcycle drives a man on a motorcycle in a race.'
#   'a man on a motorcycle on a dirty bike in multi-colored protective clothing and a helmet rotating on top of a sand dune with sand splashing into the tail of a rooster behind a motorcycle.'
#   'neutral']
#  ['a small family likes to relax on the street.'
#   'A man, woman and child are resting on the street.' 'neutral']
#  ['two men are discussing meat.'
#   'two men point to the meat in the window.' 'entailment']
#  ['four boys were wet by the pool.'
#   'four boys in swimming trunks rest on the cement edge of the pool with their feet in the water.'
#   'entailment']]
# size of set: 61737
# 42015
# 42025
# 42035
# 42045
# 42045
# 42055
# 42065
# 42075
# 42085
# 42095
# 42105
# Successful augmented objects, bad examples: 42105 3489
# Done in 45.31
# 5 random saved objects:
# [['The boy does tricks in the sand.'
#   'A boy in black clothes makes a wheel on the beach.' 'entailment']
#  ['cherry picker works on a tree.'
#   'the man in the cherry is a palm picker.' 'entailment']
#  ['man rides a boar at night with a hunter chasing him'
#   'A man in a denim jacket is looking at something in the evening.'
#   'contradiction']
#  ['woman wants to attract attention.'
#   'A woman in orange clothes is dancing in the street.' 'neutral']
#  ['people on stage' 'string quartet plays on stage.' 'entailment']]
# size of set: 61852
# 42115
# 42115
# 42115
# 42125
# 42135
# 42145
# 42155
# 42165
# 42175
# 42185
# 42195
# 42205
# Successful augmented objects, bad examples: 42205 3499
# Done in 47.16
# 5 random saved objects:
# [['the child is playing.'
#   'A boy in a red USA T-shirt is playing with a toy on the circuit board.'
#   'entailment']
#  ['woman blows away seeds from a dandelion in a field'
#   'woman blowing dandelion seeds.' 'neutral']
#  ['a man leaves his wife because he has to go to the bathroom.'
#   'the man leaves the escalator, and the woman climbs the escalator.'
#   'neutral']
#  ['the boy carries his things in his arms.'
#   'a girl sitting behind a cart full of different things.'
#   'contradiction']
#  ['The boy licks his fork.'
#   'a boy of 10 years old with short blond hair sits in a pan with cinnamon rolls and licks a spoon.'
#   'contradiction']]
# size of set: 61962
# 42215
# 42225
# 42235
# 42235
# 42245
# 42245
# 42255
# 42265
# 42275
# 42275
# 42285
# 42295
# 42305
# Successful augmented objects, bad examples: 42305 3507
# Done in 47.64
# 5 random saved objects:
# [['black dog swims.'
#   'black dog swims in green water with something in his mouth.'
#   'entailment']
#  ['the guy was lying on the beach.' 'guy surfing in the ocean'
#   'contradiction']
#  ['two dogs indoors.'
#   'two bright dogs pull on a blue object that is in their mouth.'
#   'neutral']
#  ['a child waiting on the platform is waiting in line.'
#   'a child in a red shirt is riding a zipper, while a shirtless child is waiting on the platform.'
#   'neutral']
#  ['There are so many people waiting in line to catch the bus, and suddenly the girl on the line points to the bus going and started smiling'
#   'one young girl in a white hat and blue dress and one young girl in a blue top with black trousers and a handbag are standing next to each other, a girl in a blue hat is pointing and smiling.'
#   'contradiction']]
# size of set: 62070
# 42315
# 42325
# 42335
# 42335
# 42345
# 42355
# 42365
# 42375
# 42385
# 42395
# 42405
# Successful augmented objects, bad examples: 42405 3521
# Done in 47.25
# 5 random saved objects:
# [['woman wears clothes.' 'on the stage is a woman in a bright suit.'
#   'contradiction']
#  ['man is sitting' 'batman belt buckle on man walking.' 'contradiction']
#  ['Parade of men going to the festival.'
#   'parade of men in a formal dress pass de credito.' 'neutral']
#  ['He is happy .'
#   'A boy in bright trousers plays the guitar and laughs with his friends.'
#   'entailment']
#  ['the old man is fishing online.'
#   'an elderly man works on a fishing net.' 'entailment']]
# size of set: 62184
# 42415
# 42425
# 42435
# 42445
# 42455
# 42465
# 42475
# 42485
# 42495
# 42505
# Successful augmented objects, bad examples: 42505 3532
# Done in 48.14
# 5 random saved objects:
# [['friends together in a picture.'
#   'photograph of a friend with two boys looking at each other while the girl is looking at the camera, smiling.'
#   'entailment']
#  ['children posing for a picture of the day class.'
#   'Four young children dressed in formal poses pose for a portrait. Two boys are in front, and two girls are behind.'
#   'neutral']
#  ['Two men sleep on the rafters.'
#   'Two men, one in a white T-shirt and the other without a shirt, are sitting on a construction site, collecting rafters using stairs and a screwdriver.'
#   'contradiction']
#  ['A man sitting on a bus is holding a newspaper.'
#   'A man in a silver coat and hat is sitting on a bus.' 'neutral']
#  ['a group of people in a casino'
#   'A snapshot of people gathered in a casino.' 'entailment']]
# size of set: 62295
# 42515
# 42525
# 42525
# 42535
# 42545
# 42545
# 42555
# 42565
# 42575
# 42575
# 42585
# 42595
# 42605
# Successful augmented objects, bad examples: 42605 3544
# Done in 48.54
# 5 random saved objects:
# [['Woman at a cello concert in high school.'
#   'a girl with blond hair holds a bottle and wears a blue-green floral bikini on a boat.'
#   'contradiction']
#  ['two women on a motorcycle have buckets and cans.'
#   'two men on a motorcycle with buckets and cans.' 'contradiction']
#  ['cyclist in the air on his bike.' 'cyclist in the air.' 'entailment']
#  ['Two men on the roof are working.'
#   'two men in caps and yellow raincoats on the roof work.' 'entailment']
#  ['dog jumps over a stone' 'girl collects dandelions on a grassy meadow.'
#   'contradiction']]
# size of set: 62407
# 42615
# 42615
# 42625
# 42635
# 42645
# 42645
# 42655
# 42665
# 42675
# 42685
# 42695
# 42705
# Successful augmented objects, bad examples: 42705 3551
# Done in 44.33
# 5 random saved objects:
# [['The kid is sleeping.'
#   'the child looks in a box filled with plastic items and a little terry cloth.'
#   'contradiction']
#  ['man is dancing.'
#   'dancer in an orange costume demonstrates her dancing skills.'
#   'entailment']
#  ['A girl talks about mammals while reading a newspaper.'
#   'girl with brown hair and in a gray sweater reads a sheet of paper in the classroom.'
#   'neutral']
#  ['man warms up to bat.' 'skier in the snow.' 'contradiction']
#  ['A young man performs tricks with his bike.'
#   'young man on a stunt bike jumps from a masonry pyramid.' 'entailment']]
# size of set: 62514
# 42715
# 42725
# 42735
# 42745
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-dc0bdef92586> in <module>()
#      24     premise, hypothesis, label = train.examples[rand_ind].hypothesis, train.examples[rand_ind].premise,                                  train.examples[rand_ind].label
#      25     joined_premise, joined_hypothesis = ' '.join(premise), ' '.join(hypothesis)
# ---> 26     back_premise, back_hypothesis = back_translation(joined_premise), back_translation(joined_hypothesis)
#      27     if joined_premise != back_premise and joined_hypothesis != back_hypothesis:
#      28         count_augmented_objects += 1
#
# <ipython-input-37-78d61a2f3f27> in back_translation(text)
#       9
#      10     forward = translate_client.translate(text, target_language=target_language)
# ---> 11     res = translate_client.translate(forward['translatedText'], target_language=source_language)
#      12     return res['translatedText']
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/translate_v2/client.py in translate(self, values, target_language, format_, source_language, customization_ids, model)
#     250         }
#     251
# --> 252         response = self._connection.api_request(method="POST", path="", data=data)
#     253
#     254         translations = response.get("data", {}).get("translations", ())
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     387             content_type=content_type,
#     388             headers=headers,
# --> 389             target_object=_target_object,
#     390         )
#     391
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/_http.py in _make_request(self, method, url, data, content_type, headers, target_object)
#     264         headers["User-Agent"] = self.user_agent
#     265
# --> 266         return self._do_request(method, url, headers, data, target_object)
#     267
#     268     def _do_request(
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/_http.py in _do_request(self, method, url, headers, data, target_object)
#     293         :returns: The HTTP response.
#     294         """
# --> 295         return self.http.request(url=url, method=method, headers=headers, data=data)
#     296
#     297     def api_request(
#
# /usr/local/lib/python3.6/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, **kwargs)
#     214
#     215         response = super(AuthorizedSession, self).request(
# --> 216             method, url, data=data, headers=request_headers, **kwargs
#     217         )
#     218
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.6/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
save_augmented_objects = pd.DataFrame(data=data, columns=['premise', 'hypothesis', 'label'])
save_augmented_objects.to_csv("drive/My Drive/text-augmentation/augmented.csv", index=False)

# %% [markdown]
# # Load saved augmented data

# %%
df = pd.read_csv("drive/My Drive/text-augmentation/translate-augmented.csv")
print(df.sample(5))
# Out:
#                                                  premise  ...          label
# 11413  ['two', 'men', 'are', 'talking', 'to', 'each',...  ...        neutral
# 31444     ['surfer', 'sunbathes', 'on', 'the', 'beach.']  ...  contradiction
# 42145                           ['man', 'is', 'sitting']  ...     entailment
# 53434  ['A', 'man', 'jumps', 'into', 'a', 'dirty', 'p...  ...        neutral
# 1862                    ['nobody', 'holds', 'equipment']  ...  contradiction
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Fulfil train object

# %%
for index, row in tqdm(df.iterrows()):
    new_example = torchtext.data.example.Example()
    new_example.premise = row.premise
    new_example.hypothesis = row.hypothesis
    new_example.label = row.label
    train.examples.append(new_example)
# Out:
# 57153it [00:11, 4995.09it/s]

# %% [markdown]
# # Build vocabulary & train on augmented data

# %%
TEXT.build_vocab(train, valid, min_freq=5)
LABEL.build_vocab(train)

# %%
print("Final size of data:", len(train.examples))
# Out:
# Final size of data: 606520

# %%
# Simple wrapper to join torchtext and catalyst API

class IteratorWrapper(DataLoader):
    __initialized__ = False

    def __init__(self, iter: iter, augmented_ratio):
        self.batch_size = iter.batch_size
        self.num_workers = 1
        self.collate_fn = None
        self.pin_memory = False
        self.drop_last = False
        self.timeout = 0
        self.worker_init_fn = None
        self.sampler = iter
        self.batch_sampler = iter
        self.__initialized__ = True

    def __iter__(self):
        return map(lambda batch: {
            'features': (batch.premise, batch.hypothesis),
            'targets': batch.label,
        }, self.batch_sampler.__iter__())

    def __len__(self):
        return len(self.batch_sampler)

# %%
# example of your hyperparameters 
# keep them as global vars or in the 'config' dict
n_layers = 4
h_size = 128
embed_dim = 512
num_epochs = 10
dropout = 0.1
batch_size = 512 # BatchNorm do not work properly with small batch sizes
augmented_ratio = 0.1
vocab_size = len(TEXT.vocab)

train_iter, valid_iter, test_iter = torchtext.data.BucketIterator.splits((train, valid, test), batch_size=batch_size, device=DEVICE)
train_iter = IteratorWrapper(train_iter, augmented_ratio=augmented_ratio)
valid_iter = IteratorWrapper(valid_iter, augmented_ratio=augmented_ratio)
test_iter = IteratorWrapper(test_iter, augmented_ratio=augmented_ratio)
 
loaders = {'train': train_iter, 'valid': valid_iter}

model = BiLstm(
    vocab_size=vocab_size,
    h_size=h_size,
    n_layers=n_layers, 
    dropout=dropout,
    padding_idx=TEXT.vocab.stoi[TEXT.pad_token],
)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, verbose=True, patience=2, factor=0.5)

# %%
logdir='wandb-log-dir-augmented'

# %%
runner = dl.SupervisedRunner(DEVICE)
runner.train(model=model, 
             loaders=loaders,
             num_epochs=num_epochs,
             logdir=logdir,
             criterion=nn.CrossEntropyLoss(),
             optimizer=optimizer, 
             scheduler=scheduler,  
             callbacks=[
                dl.callbacks.CheckpointCallback(2),
                dl.callbacks.AccuracyCallback(),
                dl.callbacks.EarlyStoppingCallback(3), # stop training, if valid loss does not improve last 3 epochs
                dl.callbacks.WandbLogger(
                    project="text-augmentation"
                )
             ],
             monitoring_params={
                 'entity': 'msaidov',
                 'project': 'text-augmentation',
                 'name': 'augmented-lstm-translate',
                 'group': 'examples',
                 'config': {
                     'model': 'bilstm',
                     'optimizer': str(optimizer),
                     'scheduler': 'plateau',
                     'early_stop': 3,
                     'vocab_size': vocab_size,
                     'h_size': h_size,
                     'n_layers': n_layers,
                     'dropout': dropout,
                     'batch_size': batch_size,
                     'embed_dim': embed_dim,
                 },
             },
#              check=True, # set if you want to check pipeline for correctness, without actual training
             verbose=True)
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning:
#
# can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/msaidov/text-augmentation" target="_blank">https://app.wandb.ai/msaidov/text-augmentation</a><br/>
#                 Run page: <a href="https://app.wandb.ai/msaidov/text-augmentation/runs/3n6anoep" target="_blank">https://app.wandb.ai/msaidov/text-augmentation/runs/3n6anoep</a><br/>
# 1/10 * Epoch (train): 100% 1185/1185 [19:48<00:00,  1.00s/it, accuracy01=0.699, loss=0.698]
# 1/10 * Epoch (valid): 100% 20/20 [00:02<00:00,  7.34it/s, accuracy01=0.649, loss=0.805]
# [2020-04-18 15:06:13,333]
# 1/10 * Epoch 1 (_base): lr=0.0010 | momentum=0.9000
# 1/10 * Epoch 1 (train): accuracy01=0.6348 | loss=0.7971
# 1/10 * Epoch 1 (valid): accuracy01=0.7131 | loss=0.6808
# 2/10 * Epoch (train): 100% 1185/1185 [19:50<00:00,  1.00s/it, accuracy01=0.705, loss=0.668]
# 2/10 * Epoch (valid): 100% 20/20 [00:02<00:00,  7.15it/s, accuracy01=0.649, loss=0.775]
# [2020-04-18 15:26:07,758]
# 2/10 * Epoch 2 (_base): lr=0.0010 | momentum=0.9000
# 2/10 * Epoch 2 (train): accuracy01=0.7079 | loss=0.6758
# 2/10 * Epoch 2 (valid): accuracy01=0.7426 | loss=0.6195
# Early exiting
# 3/10 * Epoch (train):   1% 9/1185 [00:11<22:13,  1.13s/it, accuracy01=0.721, loss=0.610]
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py:677: ResourceWarning:
#
# unclosed <ssl.SSLSocket fd=93, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.28.0.2', 56668), raddr=('35.186.228.49', 443)>

# %%
#  Evaluate on the test setsssssssss

runner = dl.SupervisedRunner()
y_pred = runner.predict_loader(model, test_iter, verbose=True)
# Do not forget, that the NN compute the class logits, from which you actually have to make prediction
y_pred = np.argmax(y_pred, axis=1)
y_true = np.concatenate([x['targets'].cpu().numpy() for x in test_iter])

test_score = accuracy_score(y_true, y_pred)
print(test_score)

# send test score to wandb
wandb.log({'acc/test': test_score})
# Out:
# 1/1 * Epoch (infer):   0% 0/20 [00:00<?, ?it/s]
# 1/1 * Epoch (infer):   0% 0/20 [00:00<?, ?it/s]
# 1/1 * Epoch (infer):   5% 1/20 [00:00<00:03,  5.04it/s]
# 1/1 * Epoch (infer):   5% 1/20 [00:00<00:03,  5.04it/s]
# 1/1 * Epoch (infer):  10% 2/20 [00:00<00:03,  5.51it/s]
# 1/1 * Epoch (infer):  10% 2/20 [00:00<00:03,  5.51it/s]
# 1/1 * Epoch (infer):  15% 3/20 [00:00<00:02,  6.15it/s]
# 1/1 * Epoch (infer):  15% 3/20 [00:00<00:02,  6.15it/s]
# 1/1 * Epoch (infer):  20% 4/20 [00:00<00:02,  6.83it/s]
# 1/1 * Epoch (infer):  20% 4/20 [00:00<00:02,  6.83it/s]
# 1/1 * Epoch (infer):  25% 5/20 [00:00<00:02,  6.83it/s]
# 1/1 * Epoch (infer):  30% 6/20 [00:00<00:01,  7.48it/s]
# 1/1 * Epoch (infer):  30% 6/20 [00:00<00:01,  7.48it/s]
# 1/1 * Epoch (infer):  35% 7/20 [00:00<00:01,  7.65it/s]
# 1/1 * Epoch (infer):  35% 7/20 [00:00<00:01,  7.65it/s]
# 1/1 * Epoch (infer):  40% 8/20 [00:01<00:01,  8.15it/s]
# 1/1 * Epoch (infer):  40% 8/20 [00:01<00:01,  8.15it/s]
# 1/1 * Epoch (infer):  45% 9/20 [00:01<00:01,  8.17it/s]
# 1/1 * Epoch (infer):  45% 9/20 [00:01<00:01,  8.17it/s]
# 1/1 * Epoch (infer):  50% 10/20 [00:01<00:01,  8.30it/s]
# 1/1 * Epoch (infer):  50% 10/20 [00:01<00:01,  8.30it/s]
# 1/1 * Epoch (infer):  55% 11/20 [00:01<00:01,  8.03it/s]
# 1/1 * Epoch (infer):  55% 11/20 [00:01<00:01,  8.03it/s]
# 1/1 * Epoch (infer):  60% 12/20 [00:01<00:01,  7.29it/s]
# 1/1 * Epoch (infer):  60% 12/20 [00:01<00:01,  7.29it/s]
# 1/1 * Epoch (infer):  65% 13/20 [00:01<00:00,  7.65it/s]
# 1/1 * Epoch (infer):  65% 13/20 [00:01<00:00,  7.65it/s]
# 1/1 * Epoch (infer):  70% 14/20 [00:01<00:00,  7.51it/s]
# 1/1 * Epoch (infer):  70% 14/20 [00:01<00:00,  7.51it/s]
# 1/1 * Epoch (infer):  75% 15/20 [00:01<00:00,  7.40it/s]
# 1/1 * Epoch (infer):  75% 15/20 [00:02<00:00,  7.40it/s]
# 1/1 * Epoch (infer):  80% 16/20 [00:02<00:00,  7.22it/s]
# 1/1 * Epoch (infer):  80% 16/20 [00:02<00:00,  7.22it/s]
# 1/1 * Epoch (infer):  85% 17/20 [00:02<00:00,  6.94it/s]
# 1/1 * Epoch (infer):  85% 17/20 [00:02<00:00,  6.94it/s]
# 1/1 * Epoch (infer):  90% 18/20 [00:02<00:00,  6.86it/s]
# 1/1 * Epoch (infer):  90% 18/20 [00:02<00:00,  6.86it/s]
# 1/1 * Epoch (infer):  95% 19/20 [00:02<00:00,  6.13it/s]
# 1/1 * Epoch (infer): 100% 20/20 [00:02<00:00,  7.49it/s]
# 0.7482695439739414
# /usr/local/lib/python3.6/dist-packages/wandb/meta.py:36: ResourceWarning:
#
# unclosed file <_io.TextIOWrapper name='wandb-log-dir-augmented/wandb/run-20200418_144620-3n6anoep/wandb-metadata.json' mode='r' encoding='UTF-8'>
#
# /usr/local/lib/python3.6/dist-packages/wandb/jupyter.py:122: ResourceWarning:
#
# unclosed <socket.socket fd=81, family=AddressFamily.AF_INET, type=2049, proto=0, laddr=('0.0.0.0', 0)>
#
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py:677: ResourceWarning:
#
# unclosed <ssl.SSLSocket fd=92, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.28.0.2', 36856), raddr=('35.186.228.49', 443)>
